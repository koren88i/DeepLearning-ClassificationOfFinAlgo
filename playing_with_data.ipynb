# %%
import pandas as pd

# %%
df = pd.read_csv("timestamps_features.csv")

# %%
df.head(100)
# Out:
#           date  symbol  angle_between  distance  num_of_ups_downs  \
# 0   1986-11-28  MSFT_0       0.000000  0.002200               0.0
# 1   1986-12-31  MSFT_0      -0.043745  0.002964               1.0
# 2   1987-01-30  MSFT_0      -0.172999  0.005983               2.0
# 3   1987-02-27  MSFT_0      -0.116116  0.008010               3.0
# 4   1987-03-31  MSFT_0      -0.177287  0.011104               4.0
# 5   1987-04-30  MSFT_0      -0.121928  0.013232               5.0
# 6   1987-05-29  MSFT_0      -0.103451  0.015038               6.0
# 7   1987-06-30  MSFT_0       0.091884  0.013434              -1.0
# 8   1987-07-31  MSFT_0       0.183389  0.010233              -2.0
# 9   1987-08-31  MSFT_0      -0.003729  0.010298               1.0
# 10  1987-09-30  MSFT_0      -0.043759  0.011062               2.0
# 11  1987-10-30  MSFT_0       0.273222  0.006293              -1.0
# 12  1987-11-30  MSFT_0       0.307260  0.000931              -2.0
# ...

# %%
df.symbol.nunique()
# Out:
# 110

# %%
df.groupby("symbol").tail(5)
# Out:
#              date   symbol  angle_between  distance  num_of_ups_downs  \
# 9      1987-08-31   MSFT_0      -0.003729  0.010298               1.0
# 10     1987-09-30   MSFT_0      -0.043759  0.011062               2.0
# 11     1987-10-30   MSFT_0       0.273222  0.006293              -1.0
# 12     1987-11-30   MSFT_0       0.307260  0.000931              -2.0
# 13     1987-12-01   MSFT_0       0.243127  0.003313              -3.0
# 24     1987-09-30   MSFT_1      -0.043759  0.011062               2.0
# 25     1987-10-30   MSFT_1       0.273222  0.006293              -1.0
# 26     1987-11-30   MSFT_1       0.307260  0.000931              -2.0
# 27     1987-12-31   MSFT_1       0.078781  0.000444              -3.0
# 28     1988-01-07   MSFT_1      -0.036153  0.000187               1.0
# 41     1987-11-30   MSFT_2       0.307260  0.000931              -2.0
# 42     1987-12-31   MSFT_2       0.078781  0.000444              -3.0
# ...

# %%
import numpy as np

# %%
np.finfo(np.float64).precision
# Out:
# 15
